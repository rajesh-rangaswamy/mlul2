# %%
import os
print(os.name)
print(os.getcwd())
# Out:
# nt
# C:\Users\rar\Documents\Term4

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
#       - os.altsep is the alternate pathname separator (None or '/')
#       - os.pathsep is the component separator used in $PATH etc
#       - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#       - os.defpath is the default search path for executables
#       - os.devnull is the file path of the null device ('/dev/null', etc.)
#
# ...

# %%
os.chdir("C:\RajeshR\Regular\pnal\ISB\Term4\MLUL2\GroupProject\msdchallenge")

# %%
import pandas as pd

# %%
df_triplets = pd.read_csv("kaggle_visible_evaluation_triplets.txt",sep="\t")

# %%
df_triplets.describe()
# Out:
#                   1
# count  1.450932e+06
# mean   3.187151e+00
# std    7.051666e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    3.000000e+00
# max    9.230000e+02

# %%
df_triplets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450932 entries, 0 to 1450931
# Data columns (total 3 columns):
# fd50c4007b68a3737fe052d5a4f78ce8aa117f3d    1450932 non-null object
# SOBONKR12A58A7A7E0                          1450932 non-null object
# 1                                           1450932 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 33.2+ MB

# %%
df_triplets.columns = ['userid','songid','playcount']

# %%
df_triplets.describe()
# Out:
#           playcount
# count  1.450932e+06
# mean   3.187151e+00
# std    7.051666e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    3.000000e+00
# max    9.230000e+02

# %%
print(df_triplets.head(3))
# Out:
#                                      userid              songid  playcount
# 0  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3          1
# 1  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOFLJQZ12A6D4FADA6          1
# 2  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOHTKMO12AB01843B0          1

# %%
print("column names")
print(df_triplets.columns.values)
# Out:
# column names
# ['userid' 'songid' 'playcount']

# %%
print(df_triplets.tail(3))
# Out:
#                                            userid              songid  \
# 1450929  5e650759ebf89012044c6d52121eeada8b0ec814  SOBRHVR12A8C133F35
# 1450930  5e650759ebf89012044c6d52121eeada8b0ec814  SOMGVYU12A8C1314FF
# 1450931  5e650759ebf89012044c6d52121eeada8b0ec814  SOTCMDJ12A6D4F8528
#
#          playcount
# 1450929          2
# 1450930          2
# 1450931          3

# %%
df_songs = pd.read_csv("kaggle_songs.txt",sep="\t")

# %%
df_songs.describe()
# Out:
#              SOAAADD12AB018A9DD 1
# count                      386212
# unique                     386212
# top     SOYUYJC12A8C13799E 370252
# freq                            1

# %%
df_songs.columns = ["songid"]

# %%
print(df_songs.columns.values)
# Out:
# ['songid']

# %%
df_songs.head()
# Out:
#                  songid
# 0  SOAAADE12A6D4F80CC 2
# 1  SOAAADF12A8C13DF62 3
# 2  SOAAADZ12A8C1334FB 4
# 3  SOAAAFI12A6D4F9C66 5
# 4  SOAAAGK12AB0189572 6

# %%
df_songs.tail()
# Out:
#                            songid
# 386207  SOZZZRJ12AB0187A75 386209
# 386208  SOZZZRV12A8C1361F1 386210
# 386209  SOZZZSR12AB01854CD 386211
# 386210  SOZZZWD12A6D4F6624 386212
# 386211  SOZZZWN12AF72A1E29 386213

# %%
df_users = pd.read_csv("kaggle_users.txt",sep="\t")

# %%
df_users.columns = ['userid']

# %%
print(df_users.columns.values)
# Out:
# ['userid']

# %%
df_users.describe()
# Out:
#                                           userid
# count                                     109999
# unique                                    109999
# top     332b032e2dc521f113a917d9a017f1deaeb2efe9
# freq                                           1

# %%
df_users.head()
# Out:
#                                      userid
# 0  d7083f5e1d50c264277d624340edaaf3dc16095b
# 1  d68dc6fc25248234590d7668a11e3335534ae4b4
# 2  9be82340a8b5ef32357fe5af957ccd54736ece95
# 3  841b2394ae3a9febbd6b06497b4a8ee8eb24b7f8
# 4  91b8fac7dc5e03f6cfaf6e2aa7171f14a8354d62

# %%
df_users.tail()
# Out:
#                                           userid
# 109994  07f2f354a2a4390624e0d04e4a555ef67e98f673
# 109995  fe752b1aa2a12dbc203c37b70881d88481c655f1
# 109996  ab79461415bb9db956def3a897886d0754ddddfb
# 109997  fc072bde2043756ea30ff07e4a5311e34825b4df
# 109998  5e650759ebf89012044c6d52121eeada8b0ec814

# %%
print(df_triplets.info())
print(df_users.info())
print(df_songs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450932 entries, 0 to 1450931
# Data columns (total 3 columns):
# userid       1450932 non-null object
# songid       1450932 non-null object
# playcount    1450932 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 33.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109999 entries, 0 to 109998
# Data columns (total 1 columns):
# userid    109999 non-null object
# dtypes: object(1)
# memory usage: 859.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386212 entries, 0 to 386211
# Data columns (total 1 columns):
# songid    386212 non-null object
# dtypes: object(1)
# memory usage: 2.9+ MB
# None

# %%
#print(df_triplets.userid.unique().shape[0])

# %%
df_songmeta = pd.read_csv("C:\RajeshR\Regular\pnal\ISB\Term4\MLUL2\GroupProject\msdchallenge\song_data.csv")

# %%
df_songmeta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
# song_id        1000000 non-null object
# title          999985 non-null object
# release        999995 non-null object
# artist_name    1000000 non-null object
# year           1000000 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 38.1+ MB

# %%
df_songmeta.columns = ['songid','title','release','artist_name','year']

# %%
df_songmeta.head()
# Out:
#                songid              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
df_merge = pd.merge(df_triplets,df_songmeta,on="songid",how="left")

# %%
df_merge.head()
# Out:
#                                      userid              songid  playcount  \
# 0  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOEGIYH12A6D4FC0E3          1
# 1  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOFLJQZ12A6D4FADA6          1
# 2  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOHTKMO12AB01843B0          1
# 3  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SODQZCY12A6D4F9D11          1
# 4  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOXLOQG12AF72A2D55          1
#
#                                                title  \
# 0  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 1                                           Tive Sim
# 2  Catch You Baby (Steve Pitron & Max Sanna Radio...
# 3                                        El Cuatrero
# 4                      Unite (2009 Digital Remaster)
#
#                             release  \
# 0   Mozart - Eine kleine Nachtmusik
# 1                  Nova Bis-Cartola
# 2                    Catch You Baby
# 3       From Argentina To The World
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1491951 entries, 0 to 1491950
# Data columns (total 7 columns):
# userid         1491951 non-null object
# songid         1491951 non-null object
# playcount      1491951 non-null int64
# title          1491950 non-null object
# release        1491951 non-null object
# artist_name    1491951 non-null object
# year           1491951 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 91.1+ MB

# %%
print(df_merge.columns.values)
# Out:
# ['userid' 'songid' 'playcount' 'title' 'release' 'artist_name' 'year']

# %%
df_merge.tail()
# Out:
#                                            userid              songid  \
# 1491946  5e650759ebf89012044c6d52121eeada8b0ec814  SOVLNXV12A6D4F706E
# 1491947  5e650759ebf89012044c6d52121eeada8b0ec814  SOVDSJC12A58A7A271
# 1491948  5e650759ebf89012044c6d52121eeada8b0ec814  SOBRHVR12A8C133F35
# 1491949  5e650759ebf89012044c6d52121eeada8b0ec814  SOMGVYU12A8C1314FF
# 1491950  5e650759ebf89012044c6d52121eeada8b0ec814  SOTCMDJ12A6D4F8528
#
#          playcount                  title  \
# 1491946          1          Ms. Fat Booty
# 1491947          2       Ain't Misbehavin
# 1491948          2              Luvstruck
# 1491949          2  Sinisten tähtien alla
# 1491950          3               The Gift
#
#                                              release  \
# 1491946  Rawkus Records - Best of Decade I 1995-2005
# 1491947                                   Summertime
# 1491948                           Hard House Anthems
# 1491949                                 Tatsum Tisal
# ...

# %%
len(df_merge)
# Out:
# 1491951

# %%
len(df_triplets)
# Out:
# 1450932
